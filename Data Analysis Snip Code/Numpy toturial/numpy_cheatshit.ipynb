# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
# <style>
#   table {
#     border-collapse: collapse;
#     width: 100%;
#   }
#   th, td {
#     border: 1px solid black;
#     padding: 8px;
#     text-align: left;
#   }
# </style>
# </head>
# <body>
#
# <h2>NumPy Keyword Reference</h2>
#
# <table>
#   <tr>
#     <th>Row</th>
#     <th>Keyword</th>
#     <th>Possible Values</th>
#     <th>Goal</th>
#     <th>Description</th>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>np.array</td>
#     <td>Array-like objects</td>
#     <td>Create a NumPy array</td>
#     <td>Convert input data to an array</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td>np.zeros</td>
#     <td>Shape, Data type</td>
#     <td>Create an array filled with zeros</td>
#     <td>Generate an array of zeros</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td>np.ones</td>
#     <td>Shape, Data type</td>
#     <td>Create an array filled with ones</td>
#     <td>Generate an array of ones</td>
#   </tr>
#   <tr>
#     <td>4</td>
#     <td>np.empty</td>
#     <td>Shape, Data type</td>
#     <td>Create an uninitialized array</td>
#     <td>Generate an array with uninitialized values</td>
#   </tr>
#   <tr>
#     <td>5</td>
#     <td>np.arange</td>
#     <td>Start, Stop, Step</td>
#     <td>Create an array with a range of values</td>
#     <td>Generate a sequence of values</td>
#   </tr>
#   <tr>
#     <td>6</td>
#     <td>np.linspace</td>
#     <td>Start, Stop, Number of samples</td>
#     <td>Create an array with linearly spaced values</td>
#     <td>Generate evenly spaced values</td>
#   </tr>
#   <tr>
#     <td>7</td>
#     <td>np.logspace</td>
#     <td>Start, Stop, Number of samples, Logarithmic scale</td>
#     <td>Create an array with logarithmically spaced values</td>
#     <td>Generate logarithmically spaced values</td>
#   </tr>
#   <tr>
#     <td>8</td>
#     <td>np.eye</td>
#     <td>Number of rows</td>
#     <td>Create a 2D identity matrix</td>
#     <td>Generate a square identity matrix</td>
#   </tr>
#   <tr>
#     <td>9</td>
#     <td>np.random.rand</td>
#     <td>Array shape</td>
#     <td>Generate random numbers from a uniform distribution</td>
#     <td>Generate random values between 0 and 1</td>
#   </tr>
#   <tr>
#     <td>10</td>
#     <td>np.random.randn</td>
#     <td>Array shape</td>
#     <td>Generate random numbers from a standard normal distribution</td>
#     <td>Generate random values from a normal distribution with mean 0 and standard deviation 1</td>
#   </tr>
#   <tr>
#     <td>11</td>
#     <td>np.random.randint</td>
#     <td>Low, High, Array shape</td>
#     <td>Generate random integers</td>
#     <td>Generate random integers within a specified range</td>
#   </tr>
#   <tr>
#     <td>12</td>
#     <td>np.reshape</td>
#     <td>New shape</td>
#     <td>Reshape an array</td>
#     <td>Change the shape of an array</td>
#   </tr>
#   <tr>
#     <td>13</td>
#     <td>np.concatenate</td>
#     <td>Sequence of arrays, Axis</td>
#     <td>Join arrays along an axis</td>
#     <td>Combine arrays along a specified axis</td>
#   </tr>
#   <tr>
#     <td>14</td>
#     <td>np.vstack</td>
#     <td>Sequence of arrays</td>
#     <td>Stack arrays vertically</td>
#     <td>Stack arrays on top of each other</td>
#   </tr>
#   <tr>
#     <td>15</td>
#     <td>np.hstack</td>
#     <td>Sequence of arrays</td>
#     <td>Stack arrays horizontally</td>
#     <td>Stack arrays side by side</td>
#   </tr>
#   <tr>
#     <td>16</td>
#     <td>np.split</td>
#     <td>Array, Indices or sections</td>
#     <td>Split an array into multiple sub-arrays</td>
#     <td>Divide an array into smaller arrays</td>
#   </tr>
#   <tr>
#     <td>17</td>
#     <td>np.max</td>
#     <td>Array</td>
#     <td>Find the maximum value</td>
#     <td>Return the maximum value in an array</td>
#   </tr>
#   <tr>
#     <td>18</td>
#     <td>np.min</td>
#     <td>Array</td>
#     <td>Find the minimum value</td>
#     <td>Return the minimum value in an array</td>
#   </tr>
#   <tr>
#     <td>19</td>
#     <td>np.mean</td>
#     <td>Array</td>
#     <td>Calculate the mean</td>
#     <td>Compute the arithmetic mean of an array</td>
#   </tr>
#   <tr>
#     <td>20</td>
#     <td>np.median</td>
#     <td>Array</td>
#     <td>Calculate the median</td>
#     <td>Compute the median value of an array</td>
#   </tr>
#   <tr>
#     <td>21</td>
#     <td>np.std</td>
#     <td>Array</td>
#     <td>Calculate the standard deviation</td>
#     <td>Compute the standard deviation of an array</td>
#   </tr>
#   <tr>
#     <td>22</td>
#     <td>np.var</td>
#     <td>Array</td>
#     <td>Calculate the variance</td>
#     <td>Compute the variance of an array</td>
#   </tr>
#   <tr>
#     <td>23</td>
#     <td>np.dot</td>
#     <td>Array, Array</td>
#     <td>
#
#
#   <tr>
#     <td>23</td>
#     <td>np.dot</td>
#     <td>Array, Array</td>
#     <td>Compute dot product</td>
#     <td>Calculate the dot product of two arrays</td>
#   </tr>
#   <tr>
#     <td>24</td>
#     <td>np.cross</td>
#     <td>Array, Array</td>
#     <td>Compute cross product</td>
#     <td>Calculate the cross product of two arrays</td>
#   </tr>
#   <tr>
#     <td>25</td>
#     <td>np.transpose</td>
#     <td>Array</td>
#     <td>Transpose an array</td>
#     <td>Swap the rows and columns of an array</td>
#   </tr>
#   <tr>
#     <td>26</td>
#     <td>np.diagonal</td>
#     <td>Array</td>
#     <td>Extract diagonal elements</td>
#     <td>Get the diagonal elements of an array</td>
#   </tr>
#   <tr>
#     <td>27</td>
#     <td>np.where</td>
#     <td>Condition, [x, y]</td>
#     <td>Find indices where condition is true</td>
#     <td>Return indices that satisfy a condition</td>
#   </tr>
#   <tr>
#     <td>28</td>
#     <td>np.unique</td>
#     <td>Array</td>
#     <td>Find unique elements</td>
#     <td>Get the unique elements of an array</td>
#   </tr>
#   <tr>
#     <td>29</td>
#     <td>np.argmax</td>
#     <td>Array</td>
#     <td>Find index of maximum value</td>
#     <td>Return the index of the maximum value in an array</td>
#   </tr>
#   <tr>
#     <td>30</td>
#     <td>np.argmin</td>
#     <td>Array</td>
#     <td>Find index of minimum value</td>
#     <td>Return the index of the minimum value in an array</td>
#   </tr>
#   <tr>
#     <td>31</td>
#     <td>np.any</td>
#     <td>Array</td>
#     <td>Test if any element is true</td>
#     <td>Check if any element in the array evaluates to True</td>
#   </tr>
#   <tr>
#     <td>32</td>
#     <td>np.all</td>
#     <td>Array</td>
#     <td>Test if all elements are true</td>
#     <td>Check if all elements in the array evaluate to True</td>
#   </tr>
#   <tr>
#     <td>33</td>
#     <td>np.save</td>
#     <td>File name, Array</td>
#     <td>Save array data to a binary file</td>
#     <td>Write array data to a binary file</td>
#   </tr>
#   <tr>
#     <td>34</td>
#     <td>np.load</td>
#     <td>File name</td>
#     <td>Load array data from a binary file</td>
#     <td>Read array data from a binary file</td>
#   </tr>
#   <tr>
#     <td>35</td>
#     <td>np.savetxt</td>
#     <td>File name, Array</td>
#     <td>Save array data to a text file</td>
#     <td>Write array data to a text file</td>
#   </tr>
#   <tr>
#     <td>36</td>
#     <td>np.loadtxt</td>
#     <td>File name</td>
#     <td>Load array data from a text file</td>
#     <td>Read array data from a text file</td>
#   </tr>
#   <tr>
#     <td>37</td>
#     <td>np.meshgrid</td>
#     <td>X values, Y values</td>
#     <td>Create coordinate grids</td>
#     <td>Generate coordinate matrices for 2D plotting</td>
#   </tr>
#   <tr>
#     <td>38</td>
#     <td>np.gradient</td>
#     <td>Array</td>
#     <td>Calculate gradient</td>
#     <td>Compute the gradient of an array</td>
#   </tr>
#   <tr>
#     <td>39</td>
#     <td>np.cov</td>
#     <td>Array, Array</td>
#     <td>Calculate covariance matrix</td>
#     <td>Compute the covariance matrix of two arrays</td>
#   </tr>
#   <tr>
#     <td>40</td>
#     <td>np.corrcoef</td>
#     <td>Array, Array</td><!-- ... (previous rows) ... -->
#
#   <tr>
#     <td>41</td>
#     <td>np.loadtxt</td>
#     <td>File name</td>
#     <td>Load array data from a text file</td>
#     <td>Read array data from a text file</td>
#   </tr>
#   <tr>
#     <td>42</td>
#     <td>np.meshgrid</td>
#     <td>X values, Y values</td>
#     <td>Create coordinate grids</td>
#     <td>Generate coordinate matrices for 2D plotting</td>
#   </tr>
#   <tr>
#     <td>43</td>
#     <td>np.gradient</td>
#     <td>Array</td>
#     <td>Calculate gradient</td>
#     <td>Compute the gradient of an array</td>
#   </tr>
#   <tr>
#     <td>44</td>
#     <td>np.cov</td>
#     <td>Array, Array</td>
#     <td>Calculate covariance matrix</td>
#     <td>Compute the covariance matrix of two arrays</td>
#   </tr>
#   <tr>
#     <td>45</td>
#     <td>np.corrcoef</td>
#     <td>Array, Array</td>
#     <td>Calculate correlation coefficient</td>
#     <td>Compute the correlation coefficient between two arrays</td>
#   </tr>
#   <tr>
#     <td>46</td>
#     <td>np.fft.fft</td>
#     <td>Array</td>
#     <td>Compute the one-dimensional discrete Fourier Transform</td>
#     <td>Calculate the discrete Fourier Transform of an array</td>
#   </tr>
#   <tr>
#     <td>47</td>
#     <td>np.fft.ifft</td>
#     <td>Array</td>
#     <td>Compute the inverse one-dimensional discrete Fourier Transform</td>
#     <td>Calculate the inverse discrete Fourier Transform of an array</td>
#   </tr>
#   <tr>
#     <td>48</td>
#     <td>np.fft.fftfreq</td>
#     <td>Number of samples, Sample spacing</td>
#     <td>Compute the frequencies for the FFT output</td>
#     <td>Calculate the frequencies associated with the FFT output</td>
#   </tr>
#   <tr>
#     <td>49</td>
#     <td>np.polyfit</td>
#     <td>x values, y values, Degree of polynomial</td>
#     <td>Fit a polynomial to data</td>
#     <td>Find the coefficients of a polynomial that fits given data</td>
#   </tr>
#   <tr>
#     <td>50</td>
#     <td>np.polyval</td>
#     <td>Polynomial coefficients, x values</td>
#     <td>Evaluate a polynomial at specific x values</td>
#     <td>Calculate the values of a polynomial at given x values</td>
#   </tr>
# </table>
#
# </body>
# </html>
# lation coefficient</td>
#     <td>Compute the correlation coefficient between two arrays</td>
#   </tr>
# </table>
#
# </body>
# </html>
