# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
# <style>
#   table {
#     border-collapse: collapse;
#     width: 100%;
#   }
#   th, td {
#     border: 1px solid black;
#     padding: 8px;
#     text-align: left;
#   }
#   th {
#     background-color: #f2f2f2;
#   }
# </style>
# </head>
# <body>
#
# <h2>Matplotlib Plot Types Cheat Sheet</h2>
#
# <table>
#   <tr>
#     <th>Plot Type</th>
#     <th>Keywords</th>
#     <th>Possible Values</th>
#     <th>Functionality</th>
#     <th>Best Use Case</th>
#   </tr>
#   <tr>
#     <td>Line Plot</td>
#     <td>x, y, color, linestyle, label</td>
#     <td>Arrays, lists, colors, linestyles, strings</td>
#     <td>Displays data points connected by lines.</td>
#     <td>Showing trends in continuous data.</td>
#   </tr>
#   <tr>
#     <td>Bar Plot</td>
#     <td>x, height, color, width, align</td>
#     <td>Arrays, lists, colors, width values, alignment</td>
#     <td>Displays data as vertical or horizontal bars.</td>
#     <td>Comparing categorical data.</td>
#   </tr>
#   <tr>
#     <td>Scatter Plot</td>
#     <td>x, y, s, c, marker</td>
#     <td>Arrays, lists, sizes, colors, markers</td>
#     <td>Displays individual data points as markers.</td>
#     <td>Visualizing relationships between two variables.</td>
#   </tr>
#   <tr>
#     <td>Histogram</td>
#     <td>x, bins, color, edgecolor, density</td>
#     <td>Arrays, bin values, colors, edge colors, boolean</td>
#     <td>Displays the distribution of continuous data.</td>
#     <td>Understanding data distribution.</td>
#   </tr>
#   <tr>
#     <td>Box Plot</td>
#     <td>x, y, notch, sym, vert</td>
#     <td>Arrays, lists, boolean, string, boolean</td>
#     <td>Displays the distribution of data using quartiles.</td>
#     <td>Identifying outliers and variability.</td>
#   </tr>
#   <!-- Add more rows for other plot types -->
# </table>
#
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
# <style>
#   table {
#     border-collapse: collapse;
#     width: 100%;
#   }
#   th, td {
#     border: 1px solid black;
#     padding: 8px;
#     text-align: left;
#   }
#   th {
#     background-color: #f2f2f2;
#   }
# </style>
# </head>
# <body>
#
# <h2>Matplotlib Plot Types Cheat Sheet</h2>
#
# <table>
#   <tr>
#     <th>No.</th>
#     <th>Plot Type</th>
#     <th>Keywords</th>
#     <th>Possible Values</th>
#     <th>Functionality</th>
#     <th>Best Use Case</th>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>Line Plot</td>
#     <td>x, y, color, linestyle, label</td>
#     <td>Arrays, lists, colors, linestyles, strings</td>
#     <td>Displays data points connected by lines.</td>
#     <td>Showing trends in continuous data.</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td>Bar Plot</td>
#     <td>x, height, color, width, align</td>
#     <td>Arrays, lists, colors, width values, alignment</td>
#     <td>Displays data as vertical or horizontal bars.</td>
#     <td>Comparing categorical data.</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td>Scatter Plot</td>
#     <td>x, y, s, c, marker</td>
#     <td>Arrays, lists, sizes, colors, markers</td>
#     <td>Displays individual data points as markers.</td>
#     <td>Visualizing relationships between two variables.</td>
#   </tr>
#   <tr>
#     <td>4</td>
#     <td>Histogram</td>
#     <td>x, bins, color, edgecolor, density</td>
#     <td>Arrays, bin values, colors, edge colors, boolean</td>
#     <td>Displays the distribution of continuous data.</td>
#     <td>Understanding data distribution.</td>
#   </tr>
#   <tr>
#     <td>5</td>
#     <td>Box Plot</td>
#     <td>x, y, notch, sym, vert</td>
#     <td>Arrays, lists, boolean, string, boolean</td>
#     <td>Displays the distribution of data using quartiles.</td>
#     <td>Identifying outliers and variability.</td>
#   </tr>
#   <tr>
#     <td>6</td>
#     <td>Pie Chart</td>
#     <td>labels, sizes, colors, explode, autopct</td>
#     <td>Strings, sizes, colors, array of values, format string</td>
#     <td>Displays proportions of a whole as sectors of a circle.</td>
#     <td>Showing composition or distribution.</td>
#   </tr>
#   <tr>
#     <td>7</td>
#     <td>Area Plot</td>
#     <td>x, y, color, label, alpha</td>
#     <td>Arrays, lists, colors, strings, transparency value</td>
#     <td>Displays data with shaded areas between lines.</td>
#     <td>Visualizing cumulative quantities.</td>
#   </tr>
#   <tr>
#     <td>8</td>
#     <td>Heatmap</td>
#     <td>data, cmap, linewidths, linecolor, annot</td>
#     <td>2D array, color map, linewidth values, color, boolean</td>
#     <td>Displays data as a color-encoded matrix.</td>
#     <td>Visualizing correlation and relationships.</td>
#   </tr>
#   <tr>
#     <td>9</td>
#     <td>Violin Plot</td>
#     <td>x, y, hue, split, inner</td>
#     <td>Arrays, lists, strings, boolean, string</td>
#     <td>Combines box plots and kernel density estimation.</td>
#     <td>Comparing distribution across categories.</td>
#   </tr>
#   <tr>
#     <td>10</td>
#     <td>Radar Chart</td>
#     <td>categories, values, color, marker, linestyle</td>
#     <td>Strings, arrays, color, string, string</td>
#     <td>Displays multivariate data on a radial grid.</td>
#     <td>Comparing multiple variables across categories.</td>
#   </tr>
#   <tr>
#     <td>11</td>
#     <td>3D Scatter Plot</td>
#     <td>x, y, z, c, marker</td>
#     <td>Arrays, lists, arrays, colors, markers</td>
#     <td>Displays individual data points in a 3D space.</td>
#     <td>Visualizing relationships in 3D.</td>
#   </tr>
#   <tr>
#     <td>12</td>
#     <td>3D Line Plot</td>
#     <td>x, y, z, color, linestyle</td>
#     <td>Arrays, lists, arrays, colors, linestyles</td>
#     <td>Displays lines in a 3D space.</td>
#     <td>Visualizing 3D trends.</td>
#   </tr>
#   <tr>
#     <td>13</td>
#     <td>3D Bar Plot</td>
#     <td>x, y, z, dx, dy</td>
#     <td>Arrays, lists, arrays, arrays, arrays</td>
#     <td>Displays 3D bars.</td>
#     <td>Comparing categorical data in a 3D space.</td>
#   </tr>
#   <tr>
#     <td>14</td>
#     <td>Hexbin Plot</td>
#     <td>x, y, gridsize, cmap, mincnt</td>
#     <td>Arrays, arrays, integer, color map, integer</td>
#     <td>Displays hexagonal binning of points.</td>
#     <td>Visualizing density of points in a scatter plot.</td>
#   </tr>
#   <tr>
#     <td>15</td>
#     <td>Polar Plot</    <td>Polar Plot</td>
#     <td>theta, r, color, linestyle, label</td>
#     <td>Arrays, arrays, colors, linestyles, strings</td>
#     <td>Displays data on a polar coordinate system.</td>
#     <td>Visualizing cyclic or angular data.</td>
#   </tr>
#   <tr>
#     <td>16</td>
#     <td>Ternary Plot</td>
#     <td>components, color, marker, linestyle, label</td>
#     <td>Arrays, colors, strings, strings, strings</td>
#     <td>Displays data on a ternary diagram.</td>
#     <td>Comparing proportions of three variables.</td>
#   </tr>
#   <tr>
#     <td>17</td>
#     <td>Quiver Plot</td>
#     <td>x, y, u, v, color</td>
#     <td>Arrays, arrays, arrays, arrays, colors</td>
#     <td>Displays vector field data using arrows.</td>
#     <td>Visualizing vector fields.</td>
#   </tr>
#   <tr>
#     <td>18</td>
#     <td>Streamplot</td>
#     <td>x, y, u, v, density</td>
#     <td>Arrays, arrays, arrays, arrays, float</td>
#     <td>Displays fluid flow using streamlines.</td>
#     <td>Visualizing fluid dynamics.</td>
#   </tr>
#   <tr>
#     <td>19</td>
#     <td>Contour Plot</td>
#     <td>X, Y, Z, levels, cmap</td>
#     <td>2D arrays, 2D arrays, 2D arrays, array, color map</td>
#     <td>Displays contour lines of 3D data on a 2D plane.</td>
#     <td>Visualizing 3D data on a 2D surface.</td>
#   </tr>
#   <tr>
#     <td>20</td>
#     <td>Surface Plot</td>
#     <td>X, Y, Z, cmap, rstride</td>
#     <td>2D arrays, 2D arrays, 2D arrays, color map, integer</td>
#     <td>Displays 3D data as a surface plot.</td>
#     <td>Visualizing 3D data in a surface form.</td>
#   </tr>
# </table>
#
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
# <style>
#   table {
#     border-collapse: collapse;
#     width: 100%;
#   }
#   th, td {
#     border: 1px solid black;
#     padding: 8px;
#     text-align: left;
#   }
# </style>
# </head>
# <body>
#
# <h2>Matplotlib Keyword Reference</h2>
#
# <table>
#   <tr>
#     <th>Row</th>
#     <th>Keyword</th>
#     <th>Possible Values</th>
#     <th>Goal</th>
#     <th>Suitable Plot Types</th>
#     <th>Code Example</th>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>plt.plot</td>
#     <td>'line', 'scatter', 'bar', ...</td>
#     <td>Display data with various plot types</td>
#     <td>Line Plot, Scatter Plot, Bar Plot</td>
#     <td>plt.plot(x_values, y_values, 'o-', label='data')</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td>plt.xlabel</td>
#     <td>Text</td>
#     <td>Set label for x-axis</td>
#     <td>All Plot Types</td>
#     <td>plt.xlabel('X-axis Label')</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td>plt.ylabel</td>
#     <td>Text</td>
#     <td>Set label for y-axis</td>
#     <td>All Plot Types</td>
#     <td>plt.ylabel('Y-axis Label')</td>
#   </tr>
#   <tr>
#     <td>4</td>
#     <td>plt.title</td>
#     <td>Text</td>
#     <td>Set title of the plot</td>
#     <td>All Plot Types</td>
#     <td>plt.title('Plot Title')</td>
#   </tr>
#   <tr>
#     <td>5</td>
#     <td>plt.legend</td>
#     <td>True, False</td>
#     <td>Display legend on the plot</td>
#     <td>Line Plot, Scatter Plot, ...</td>
#     <td>plt.legend()</td>
#   </tr>
#   <tr>
#     <td>6</td>
#     <td>plt.xlim</td>
#     <td>Tuple of two numbers</td>
#     <td>Set x-axis limits</td>
#     <td>Line Plot, Scatter Plot, ...</td>
#     <td>plt.xlim(0, 10)</td>
#   </tr>
#   <tr>
#     <td>7</td>
#     <td>plt.ylim</td>
#     <td>Tuple of two numbers</td>
#     <td>Set y-axis limits</td>
#     <td>Line Plot, Scatter Plot, ...</td>
#     <td>plt.ylim(0, 50)</td>
#   </tr>
#   <tr>
#     <td>8</td>
#     <td>plt.grid</td>
#     <td>True, False</td>
#     <td>Display grid lines</td>
#     <td>All Plot Types</td>
#     <td>plt.grid(True)</td>
#   </tr>
#   <tr>
#     <td>9</td>
#     <td>plt.bar</td>
#     <td>Data values, Bar properties</td>
#     <td>Create bar plot</td>
#     <td>Bar Plot</td>
#     <td>plt.bar(x_values, y_values, color='blue')</td>
#   </tr>
#   <tr>
#     <td>10</td>
#     <td>plt.scatter</td>
#     <td>x values, y values, Marker properties</td>
#     <td>Create scatter plot</td>
#     <td>Scatter Plot</td>
#     <td>plt.scatter(x_values, y_values, marker='o')</td>
#   </tr>
# <!-- ... (previous rows) ... -->
#
#   <tr>
#     <td>11</td>
#     <td>plt.hist</td>
#     <td>Data values, Binning options</td>
#     <td>Create histogram</td>
#     <td>Histogram</td>
#     <td>plt.hist(data_values, bins=10)</td>
#   </tr>
#   <tr>
#     <td>12</td>
#     <td>plt.pie</td>
#     <td>Data values, Labels, Pie properties</td>
#     <td>Create pie chart</td>
#     <td>Pie Chart</td>
#     <td>plt.pie(data_values, labels=categories)</td>
#   </tr>
#   <tr>
#     <td>13</td>
#     <td>plt.boxplot</td>
#     <td>Data values, Boxplot properties</td>
#     <td>Create box plot</td>
#     <td>Box Plot</td>
#     <td>plt.boxplot(data_values)</td>
#   </tr>
#   <tr>
#     <td>14</td>
#     <td>plt.subplot</td>
#     <td>Row, Column, Index</td>
#     <td>Create subplots in a grid</td>
#     <td>Subplots</td>
#     <td>plt.subplot(2, 2, 1)</td>
#   </tr>
#   <tr>
#     <td>15</td>
#     <td>plt.subplots</td>
#     <td>Row, Column, Share axes properties</td>
#     <td>Create a grid of subplots</td>
#     <td>Subplots</td>
#     <td>fig, axs = plt.subplots(2, 2, sharex=True, sharey=True)</td>
#   </tr>
#   <tr>
#     <td>16</td>
#     <td>plt.imshow</td>
#     <td>Image data, Colormap</td>
#     <td>Display images</td>
#     <td>Image Plot</td>
#     <td>plt.imshow(image_data, cmap='viridis')</td>
#   </tr>
#   <tr>
#     <td>17</td>
#     <td>plt.contour</td>
#     <td>X, Y, Z values, Contour properties</td>
#     <td>Create contour plots</td>
#     <td>Contour Plot</td>
#     <td>plt.contour(X, Y, Z, levels=20)</td>
#   </tr>
#   <tr>
#     <td>18</td>
#     <td>plt.plot_surface</td>
#     <td>X, Y, Z values, Surface properties</td>
#     <td>Create 3D surface plot</td>
#     <td>3D Surface Plot</td>
#     <td>ax.plot_surface(X, Y, Z, cmap='viridis')</td>
#   </tr>
#   <tr>
#     <td>19</td>
#     <td>plt.barh</td>
#     <td>Data values, Bar properties</td>
#     <td>Create horizontal bar plot</td>
#     <td>Horizontal Bar Plot</td>
#     <td>plt.barh(y_values, x_values, color='green')</td>
#   </tr>
#   <tr>
#     <td>20</td>
#     <td>plt.stem</td>
#     <td>X, Y values, Marker properties</td>
#     <td>Create stem plot</td>
#     <td>Stem Plot</td>
#     <td>plt.stem(x_values, y_values, markerfmt='ro-')</td>
#   </tr>
# <!-- ... (previous rows) ... -->
#
#   <tr>
#     <td>21</td>
#     <td>plt.errorbar</td>
#     <td>X, Y values, Error values, Errorbar properties</td>
#     <td>Add error bars to plots</td>
#     <td>Error Bar Plot</td>
#     <td>plt.errorbar(x_values, y_values, yerr=errors, fmt='o')</td>
#   </tr>
#   <tr>
#     <td>22</td>
#     <td>plt.annotate</td>
#     <td>Text, xy point, xytext point</td>
#     <td>Add annotation to a plot</td>
#     <td>All Plot Types</td>
#     <td>plt.annotate('Important Point', xy=(x, y), xytext=(x_text, y_text), ...)</td>
#   </tr>
#   <tr>
#     <td>23</td>
#     <td>plt.fill_between</td>
#     <td>x values, y values, Alpha value</td>
#     <td>Fill area between curves</td>
#     <td>Area Plot</td>
#     <td>plt.fill_between(x_values, y1_values, y2_values, alpha=0.5)</td>
#   </tr>
#   <tr>
#     <td>24</td>
#     <td>plt.quiver</td>
#     <td>X, Y, U, V values, Quiver properties</td>
#     <td>Display vector field</td>
#     <td>Quiver Plot</td>
#     <td>plt.quiver(x_values, y_values, u_values, v_values)</td>
#   </tr>
#   <tr>
#     <td>25</td>
#     <td>plt.stem</td>
#     <td>X, Y values, Marker properties</td>
#     <td>Create stem plot</td>
#     <td>Stem Plot</td>
#     <td>plt.stem(x_values, y_values, markerfmt='ro-')</td>
#   </tr>
#   <tr>
#     <td>26</td>
#     <td>plt.plot_date</td>
#     <td>Date values, y values, Line properties</td>
#     <td>Create plot with date values</td>
#     <td>Date Plot</td>
#     <td>plt.plot_date(date_values, y_values, linestyle='solid')</td>
#   </tr>
#   <tr>
#     <td>27</td>
#     <td>plt.xkcd</td>
#     <td>N/A</td>
#     <td>Create plots with XKCD-style aesthetics</td>
#     <td>All Plot Types</td>
#     <td>with plt.xkcd():</td>
#   </tr>
#   <tr>
#     <td>28</td>
#     <td>plt.style</td>
#     <td>Style name</td>
#     <td>Set plot style</td>
#     <td>All Plot Types</td>
#     <td>plt.style.use('ggplot')</td>
#   </tr>
#   <tr>
#     <td>29</td>
#     <td>plt.savefig</td>
#     <td>File name, Format</td>
#     <td>Save the plot as an image file</td>
#     <td>All Plot Types</td>
#     <td>plt.savefig('plot.png', format='png')</td>
#   </tr>
#   <tr>
#     <td>30</td>
#     <td>plt.show</td>
#     <td>N/A</td>
#     <td>Display the plot</td>
#     <td>All Plot Types</td>
#     <td>plt.show()</td>
#   </tr>
# </table>
#
# </body>
# </html>
