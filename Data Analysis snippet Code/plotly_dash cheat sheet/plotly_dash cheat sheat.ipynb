# %% [markdown]
# <table>
#   <thead>
#     <tr>
#       <th>Row</th>
#       <th>Function/Method</th>
#       <th>Description</th>
#       <th>Top 5 Important Parameters</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td><code>plotly.graph_objects.Figure</code></td>
#       <td>Create a Figure object to hold visualizations.</td>
#       <td>Data, Layout, Config, Frames, Data Validation</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td><code>plotly.graph_objects.Scatter</code></td>
#       <td>Create a scatter plot trace.</td>
#       <td>x, y, mode, marker, line</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td><code>plotly.graph_objects.Bar</code></td>
#       <td>Create a bar chart trace.</td>
#       <td>x, y, orientation, marker, hoverinfo</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td><code>plotly.graph_objects.Line</code></td>
#       <td>Create a line chart trace.</td>
#       <td>x, y, mode, line, marker</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td><code>plotly.graph_objects.Layout</code></td>
#       <td>Create a layout for configuring the appearance of the visualization.</td>
#       <td>title, xaxis, yaxis, margin, legend</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td><code>plotly.subplots.make_subplots</code></td>
#       <td>Create subplots in a single figure.</td>
#       <td>rows, cols, subplot_titles, shared_xaxes, shared_yaxes</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td><code>plotly.express.scatter</code></td>
#       <td>Create a scatter plot quickly using Plotly Express.</td>
#       <td>data_frame, x, y, color, size</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td><code>plotly.express.bar</code></td>
#       <td>Create a bar chart quickly using Plotly Express.</td>
#       <td>data_frame, x, y, color, animation_frame</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td><code>plotly.express.line</code></td>
#       <td>Create a line chart quickly using Plotly Express.</td>
#       <td>data_frame, x, y, color, line_group</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td><code>plotly.offline.plot</code></td>
#       <td>Create and display interactive plots offline.</td>
#       <td>figure_or_data, show_link, validate, output_type, include_plotlyjs</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td><code>plotly.subplots.make_subplots</code></td>
#       <td>Create subplots using the <code>make_subplots</code> function.</td>
#       <td>rows, cols, specs, subplot_titles, shared_xaxes</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td><code>plotly.graph_objects.Histogram</code></td>
#       <td>Create a histogram trace.</td>
#       <td>x, nbins, histnorm, cumulative, barmode</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td><code>plotly.graph_objects.Box</code></td>
#       <td>Create a box plot trace.</td>
#       <td>x, y, boxpoints, notched, pointpos</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td><code>plotly.graph_objects.Heatmap</code></td>
#       <td>Create a heatmap trace.</td>
#       <td>z, x, y, colorscale, colorbar</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td><code>plotly.graph_objects.Pie</code></td>
#       <td>Create a pie chart trace.</td>
#       <td>labels, values, textinfo, pull, hole</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td><code>plotly.graph_objects.FigureWidget</code></td>
#       <td>Create an interactive FigureWidget for live updates.</td>
#       <td>data, layout, config, widget, events</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td><code>plotly.subplots.subplots</code></td>
#       <td>Create subplots with more customization options.</td>
#       <td>rows, cols, subplot_titles, specs, shared_xaxes</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td><code>dash.Dash</code></td>
#       <td>Initialize a Dash web application.</td>
#       <td>__name__, external_stylesheets, url_base_pathname, suppress_callback_exceptions, title</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td><code>dash_core_components.Graph</code></td>
#       <td>Create an interactive graph component for Dash.</td>
#       <td>id, figure, config, style, animate</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td><code>dash_core_components.Dropdown</code></td>
#       <td>Create a dropdown component for selecting options.</td>
#       <td>options, value, multi, disabled, style</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td><code>dash_core_components.Slider</code></td>
#       <td>Create a slider component for selecting numerical values.</td>
#       <td>min, max, step, value, marks</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td><code>dash_html_components.Div</code></td>
#       <td>Create a container div for organizing layout in Dash.</td>
#       <td>children, id, style, className, hidden</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td><code>dash_html_components.H1</code></td>
#       <td>Create an H1 heading in Dash.</td>
#       <td>children, id, style, className, hidden</td>
#     </tr>
#     <tr>
#       <td
#
# >24</td>
#       <td><code>dash.dependencies.Input</code></td>
#       <td>Define an input for a callback function in Dash.</td>
#       <td>component_id, component_property, event, state, prevent_initial_call</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td><code>dash.dependencies.Output</code></td>
#       <td>Define an output for a callback function in Dash.</td>
#       <td>component_id, component_property, event, prevent_initial_call, transform</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td><code>dash.dependencies.State</code></td>
#       <td>Define a state for a callback function in Dash.</td>
#       <td>component_id, component_property, event, prevent_initial_call, transform</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td><code>dcc.Interval</code></td>
#       <td>Create an interval component for triggering periodic updates in Dash.</td>
#       <td>id, interval, n_intervals, max_intervals, disabled</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td><code>dash.callback_context</code></td>
#       <td>Access information about the current callback context in Dash.</td>
#       <td>triggered_id, triggered_value, triggered_prop_id, triggered_prop_value, triggered_inputs</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td><code>dash.exceptions.PreventUpdate</code></td>
#       <td>Signal to prevent a callback from updating its output.</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td><code>dash_html_components.Table</code></td>
#       <td>Create an HTML table in Dash.</td>
#       <td>children, id, style, className, hidden</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td><code>dash_core_components.RangeSlider</code></td>
#       <td>Create a range slider component in Dash.</td>
#       <td>min, max, step, value, marks</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td><code>dash_core_components.Checklist</code></td>
#       <td>Create a checklist component for selecting multiple options.</td>
#       <td>options, value, inline, style, className</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td><code>dash_core_components.RadioItems</code></td>
#       <td>Create a radio items component for selecting a single option.</td>
#       <td>options, value, inline, style, className</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td><code>dash_core_components.Markdown</code></td>
#       <td>Render Markdown text in Dash.</td>
#       <td>children, id, style, className, hidden</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td><code>dash_html_components.P</code></td>
#       <td>Create a paragraph element in Dash.</td>
#       <td>children, id, style, className, hidden</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td><code>dash_html_components.Button</code></td>
#       <td>Create a button component in Dash.</td>
#       <td>children, id, n_clicks, disabled, style</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td><code>dash_html_components.Input</code></td>
#       <td>Create an input component in Dash.</td>
#       <td>children, id, value, type, style</td>
#     </tr>
#   </tbody>
# </table>
